# %% [markdown]
# # Crowd Count Using MCNN
#
# An (**SUPER UGLY**) implementation of CVPR2016 paper [Single-Image Crowd Counting via Multi-Column Convolutional Neural Network](https://www.cv-foundation.org/openaccess/content_cvpr_2016/papers/Zhang_Single-Image_Crowd_Counting_CVPR_2016_paper.pdf)
#
# ** This is my first version of implementation, please see v2 for cleaner version **
#
# This code use the pre-trained weight from this [github](https://github.com/uestcchicken/crowd-counting-MCNN)
#
# We use Keras as an implementation **ONLY**

# %% [markdown]
# ## Import required library

# %%
import keras
import numpy as np
import os 
import cv2
import matplotlib.pyplot as plt
import math
from keras import models
from keras.preprocessing.image import ImageDataGenerator
import scipy.io
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Define Necessary Function
#
# `test_preprocessing` function recieves **PATH of images** and **dataset name** and returns preprocessed data.
# The preprocessing methods include:
# - Loading images in B/W , `cv.imread(img,0)`
# - Normalize Image, `(img-127.5)/128`
#
# `train_preprocessing` function receives **PATH of training images** and **PATH of density images**. It returns truple of loaded train image and density.
#
# `get_cost_diff_epochs` function receives **min and max epochs** for displaying the different MSE of each epoch.

# %%
def test_preprocessing(img_path, dataset):
    print('loading data from dataset', dataset, '...')
    img_names = os.listdir(img_path)
    img_num = len(img_names)
    img_names.sort()

    data = []
    i = 1
    for name in img_names:
        if name == '.DS_Store':
            continue
        if i % 50 == 0:
            print(i, '/', img_num)
        img = cv2.imread(img_path + name, 0)
        print(img_path+name)
        img = (img - 127.5) / 128
        data.append(img)
        i += 1
    
    print('load data finished.')
    return data

def train_preprocessing(img_path, den_path):
        print('loading training data...')
        img_names = os.listdir(img_path)
        img_num = len(img_names)
        img_names.sort()
        
        data = []
        density = []
        count = 1
        for name in img_names:
            if count % 100 == 0:
                print(count, '/', img_num)
            count += 1
            img = cv2.imread(img_path + name, 0)
            img = np.array(img)
            img = (img - 127.5) / 128
            den = np.loadtxt(open(den_path + name[:-4] + '.csv'), delimiter = ",")
            den_quarter = np.zeros((int(den.shape[0] / 4), int(den.shape[1] / 4)))
            for i in range(len(den_quarter)):
                for j in range(len(den_quarter[0])):
                    for p in range(4):
                        for q in range(4):
                            den_quarter[i][j] += den[i * 4 + p][j * 4 + q]
            data.append(np.reshape(img, [img.shape[0], img.shape[1], 1]))
            density.append(np.reshape(den_quarter, [den_quarter.shape[0], den_quarter.shape[1], 1]))
        data = np.array(data)
        density = np.array(density)
        print('load training data finished')
        return (data, density)
    
def get_ground_truth(dataset):
    gt_path = 'icanteen_img/'+dataset+'/ground_truth/'
    gt_names = os.listdir(gt_path)
    gt_names.sort()
    gt = []
    i = 1
    for file in gt_names:
        if file == '.DS_Store':
            continue
        mat = scipy.io.loadmat(gt_path+file)
        gt.append(mat['image_info'][0][0][0][0][1][0][0])
        i += 1
    return gt

# %% [markdown]
# ## Creating MCNN model with Keras
# The structure of MCNN network for crowd counting is as follow:
# ![network](MCNN.png)
# `Conv2D(out_channel, kernel_size, padding, activation)` <br>
# - Apply a 2D convolution layer with an output channel of `out-channel`, kernel size of `kernel_size`, and activation function `activation`.
#
# `MaxPooling2D(pool_size, stride)`
# - Apply a 2D max pooling layer with a pool size of `pool_size`. If the `stride` argument is left blank, the value will equal to `pool_size`.
#
# `concatnate([out1, out2, ...])`
# - Concat many layers(`out1, out2, ...`) together. Note that all outputs must be equal in size.

# %%
from keras.layers import Dense, Input, Conv2D, MaxPooling2D, concatenate
from keras.models import Model
from keras.optimizers import Adam, SGD

def get_MCNN():    
    input1 = Input(shape=(None, None, 1)) 
    
    # S
    xs = Conv2D(24, kernel_size = (5,5), padding = 'same', activation = 'relu')(input1)   
    xs = MaxPooling2D(pool_size = (2,2))(xs)
    xs = Conv2D(48, kernel_size = (3,3), padding = 'same', activation = 'relu')(xs)
    xs = MaxPooling2D(pool_size = (2,2))(xs)
    xs = Conv2D(24, kernel_size = (3,3), padding = 'same', activation = 'relu')(xs)
    xs = Conv2D(12, kernel_size = (3,3), padding = 'same', activation = 'relu')(xs)
    
    # M
    xm = Conv2D(20, kernel_size = (7,7), padding = 'same', activation = 'relu')(input1)   
    xm = MaxPooling2D(pool_size = (2,2))(xm)
    xm = Conv2D(40, kernel_size = (5,5), padding = 'same', activation = 'relu')(xm)
    xm = MaxPooling2D(pool_size = (2,2))(xm)
    xm = Conv2D(20, kernel_size = (5,5), padding = 'same', activation = 'relu')(xm)
    xm = Conv2D(10, kernel_size = (5,5), padding = 'same', activation = 'relu')(xm)
    
    # L
    xl = Conv2D(16, kernel_size = (9,9), padding = 'same', activation = 'relu')(input1)   
    xl = MaxPooling2D(pool_size = (2,2))(xl)
    xl = Conv2D(32, kernel_size = (7,7), padding = 'same', activation = 'relu')(xl)
    xl = MaxPooling2D(pool_size = (2,2))(xl)
    xl = Conv2D(16, kernel_size = (7,7), padding = 'same', activation = 'relu')(xl)
    xl = Conv2D(8, kernel_size = (7,7), padding = 'same', activation = 'relu')(xl)
    
    x = concatenate([xm, xs, xl])
    out = Conv2D(1, kernel_size = (1,1), padding = 'same')(x)
    
    model = Model(inputs=input1, outputs=out)
    model.compile(optimizer=SGD(0.01),
                loss='mse',
                metrics=['mean_absolute_error'])

    return model

# %%
train_path = 'image_preprocessor/data/formatted_trainval/icanteen_patches/train/'
train_path_den = 'image_preprocessor/data/formatted_trainval/icanteen_patches/train_den/'
val_path = 'image_preprocessor/data/formatted_trainval/icanteen_patches/val/'
val_path_den = 'image_preprocessor/data/formatted_trainval/icanteen_patches/val_den/'

train, train_den = train_preprocessing(train_path, train_path_den)
val, val_den = train_preprocessing(val_path, val_path_den)
# Out:
# loading training data...
# 100 / 252
# 200 / 252
# load training data finished
# loading training data...
# load training data finished

# %% [markdown]
# ## Get and load a model
# Initialize the model with `get_MCNN()` and load pre-trained weights.
#
# `model.summary()` is used to get the model summary.

# %%
model = get_MCNN()
model.load_weights('keras_weight/weights.h5')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, None, None, 1 0
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 2 1000        input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 624         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 1 1312        input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, None, None, 2 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, None, None, 2 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, None, None, 1 0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 4 20040       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 4 10416       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 3 25120       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, None, None, 4 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, None, None, 4 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, None, None, 3 0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 2 20020       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 2 10392       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 1 25104       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 1 5010        conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 2604        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 8 6280        conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 3 0           conv2d_21[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 1 31          concatenate_2[0][0]
# ==================================================================================================
# Total params: 127,953
# Trainable params: 127,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Predict results from the loaded weight

# %%
test_path = 'icanteen_img/test/images/'
data = test_preprocessing(test_path, 'icanteen')
# Out:
# loading data from dataset icanteen ...
# icanteen_img/test/images/IMG_1.jpg
# icanteen_img/test/images/IMG_10.jpg
# icanteen_img/test/images/IMG_11.jpg
# icanteen_img/test/images/IMG_12.jpg
# icanteen_img/test/images/IMG_13.jpg
# icanteen_img/test/images/IMG_14.jpg
# icanteen_img/test/images/IMG_15.jpg
# icanteen_img/test/images/IMG_16.jpg
# icanteen_img/test/images/IMG_17.jpg
# icanteen_img/test/images/IMG_18.jpg
# icanteen_img/test/images/IMG_19.jpg
# icanteen_img/test/images/IMG_2.jpg
# icanteen_img/test/images/IMG_20.jpg
# icanteen_img/test/images/IMG_21.jpg
# icanteen_img/test/images/IMG_22.jpg
# icanteen_img/test/images/IMG_23.jpg
# icanteen_img/test/images/IMG_24.jpg
# icanteen_img/test/images/IMG_25.jpg
# icanteen_img/test/images/IMG_26.jpg
# icanteen_img/test/images/IMG_27.jpg
# icanteen_img/test/images/IMG_28.jpg
# icanteen_img/test/images/IMG_29.jpg
# icanteen_img/test/images/IMG_3.jpg
# icanteen_img/test/images/IMG_30.jpg
# icanteen_img/test/images/IMG_4.jpg
# icanteen_img/test/images/IMG_5.jpg
# icanteen_img/test/images/IMG_6.jpg
# icanteen_img/test/images/IMG_7.jpg
# icanteen_img/test/images/IMG_8.jpg
# icanteen_img/test/images/IMG_9.jpg
# load data finished.

# %%
mae = 0
mse = 0
ground_truth = get_ground_truth('test')
pred = []

i = 0
for d in data:
    inputs = np.reshape(d, [1, d.shape[0], d.shape[1], 1])
    outputs = model.predict(inputs)
    c_pre = round(np.sum(outputs))
    pred.append(c_pre)
    print('='*10+'IMG_'+str(i+31)+'.jpg'+'='*10)
    mae += abs(ground_truth[i]-c_pre)
    mse += (ground_truth[i]-c_pre)**2
    print('ERROR:',abs(ground_truth[i]-c_pre))
    i += 1
    
print('Mean Absolute Error:',mae/len(ground_truth))
print('Mean Square Error:',math.sqrt(mse/len(ground_truth)))

plt.figure(figsize=(20, 10))
plt.plot(np.arange(1, len(data)+1),ground_truth, marker='x')
plt.plot(np.arange(1,len(data)+1),pred, marker='x')
plt.xticks(np.arange(1,len(data)+1))
plt.xlabel('Img no.')
plt.ylabel('People')
plt.legend(['ground truth', 'pred'])
plt.title('Head counts Actual vs Predict')
plt.show()
# Out:
# ==========IMG_31.jpg==========
# ERROR: 26.0
# ==========IMG_32.jpg==========
# ERROR: 32.0
# ==========IMG_33.jpg==========
# ERROR: 62.0
# ==========IMG_34.jpg==========
# ERROR: 35.0
# ==========IMG_35.jpg==========
# ERROR: 39.0
# ==========IMG_36.jpg==========
# ERROR: 33.0
# ==========IMG_37.jpg==========
# ERROR: 35.0
# ==========IMG_38.jpg==========
# ERROR: 50.0
# ==========IMG_39.jpg==========
# ERROR: 39.0
# ==========IMG_40.jpg==========
# ERROR: 51.0
# Mean Absolute Error: 40.2
# Mean Square Error: 41.50421665325103

# %% [markdown]
# ## Select optimum epoch that yield the least MAE

# %%
def get_cost_diff_epochs(min_epoch, max_epoch):
    
    val_path = 'icanteen_img/val_epoch/images/'
    data = test_preprocessing(val_path, 'icanteen')
    
    mean_absolute_error = []
    mean_square_error = []
    for i in range(min_epoch, max_epoch+1):
        print('='*20,'TRAINING EPOCH =',i,'='*20)
        # Load network
        model = get_MCNN()
        model.load_weights('keras_weight/weights.h5')

        # Fine-tune only last 2 layers
        for layer in model.layers[:-2]:
            layer.trainable = False

        # Load fine-tune model
        mcnn = models.Sequential()
        mcnn.add(model)

        # set epochs and batch_size
        epochs = i
        batch_size = 1

        # load train, val
        aug = ImageDataGenerator()
        train_generator = aug.flow(train, train_den, batch_size = batch_size, shuffle = True)
        val_generator = aug.flow(val, val_den, batch_size = batch_size, shuffle = True)  

        # compile and train model
        mcnn.compile(loss='mae',
                  optimizer=Adam(0.0001),
                  metrics=['mae'])

        print('start training MCNN...')
        print("train with {} epochs and {} batch size".format(epochs, batch_size))
        history = mcnn.fit_generator(train_generator,
                                    steps_per_epoch = math.ceil(train.shape[0]/train_generator.batch_size),
                                    epochs = epochs,
                                    validation_data = val_generator,
                                    validation_steps = math.ceil(val.shape[0]/val_generator.batch_size),
                                    verbose = 1)


        mae = 0
        mse = 0
        ground_truth = get_ground_truth('val_epoch')
        pred = []

        i = 0
        for d in data:
            if i>len(ground_truth)-1:
                continue
            inputs = np.reshape(d, [1, d.shape[0], d.shape[1], 1])
            outputs = model.predict(inputs)
            c_pre = round(np.sum(outputs))
            pred.append(c_pre)
            mae += abs(ground_truth[i]-c_pre)
            mse += (ground_truth[i]-c_pre)**2
            i += 1

        mean_absolute_error.append(mae/len(ground_truth))
        mean_square_error.append(math.sqrt(mse/len(ground_truth)))
    
    return (mean_absolute_error, mean_square_error)

# %%
min_epochs = 1
max_epochs = 10
mean_abs_err, mean_sqr_err = get_cost_diff_epochs(min_epochs,max_epochs)
# Out:
# loading data from dataset icanteen ...
# load data finished.
# ==================== TRAINING EPOCH = 1 ====================
# start training MCNN...
# train with 1 epochs and 1 batch size
# Epoch 1/1
# 252/252 [==============================] - 3s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0018 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# ==================== TRAINING EPOCH = 2 ====================
# start training MCNN...
# train with 2 epochs and 1 batch size
# Epoch 1/2
# 252/252 [==============================] - 3s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0018 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 2/2
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# ==================== TRAINING EPOCH = 3 ====================
# start training MCNN...
# train with 3 epochs and 1 batch size
# Epoch 1/3
# 252/252 [==============================] - 3s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0018 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 2/3
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 3/3
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# ==================== TRAINING EPOCH = 4 ====================
# start training MCNN...
# train with 4 epochs and 1 batch size
# Epoch 1/4
# 252/252 [==============================] - 3s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0018 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 2/4
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 3/4
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 4/4
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# ==================== TRAINING EPOCH = 5 ====================
# start training MCNN...
# train with 5 epochs and 1 batch size
# Epoch 1/5
# 252/252 [==============================] - 3s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0018 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 2/5
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 3/5
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 4/5
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 5/5
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0015 - val_mean_absolute_error: 0.0015
# ==================== TRAINING EPOCH = 6 ====================
# start training MCNN...
# train with 6 epochs and 1 batch size
# Epoch 1/6
# 252/252 [==============================] - 3s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0018 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 2/6
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 3/6
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 4/6
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 5/6
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0015 - val_mean_absolute_error: 0.0015
# Epoch 6/6
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0015 - val_mean_absolute_error: 0.0015
# ==================== TRAINING EPOCH = 7 ====================
# start training MCNN...
# train with 7 epochs and 1 batch size
# Epoch 1/7
# 252/252 [==============================] - 3s 14ms/step - loss: 0.0018 - mean_absolute_error: 0.0018 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 2/7
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 3/7
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 4/7
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 5/7
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0015 - val_mean_absolute_error: 0.0015
# Epoch 6/7
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0015 - val_mean_absolute_error: 0.0015
# Epoch 7/7
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - val_loss: 0.0015 - val_mean_absolute_error: 0.0015
# ==================== TRAINING EPOCH = 8 ====================
# start training MCNN...
# train with 8 epochs and 1 batch size
# Epoch 1/8
# 252/252 [==============================] - 3s 14ms/step - loss: 0.0018 - mean_absolute_error: 0.0018 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 2/8
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 3/8
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 4/8
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 5/8
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0015 - val_mean_absolute_error: 0.0015
# Epoch 6/8
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0015 - val_mean_absolute_error: 0.0015
# Epoch 7/8
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - val_loss: 0.0014 - val_mean_absolute_error: 0.0014
# Epoch 8/8
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - val_loss: 0.0014 - val_mean_absolute_error: 0.0014
# ==================== TRAINING EPOCH = 9 ====================
# start training MCNN...
# train with 9 epochs and 1 batch size
# Epoch 1/9
# 252/252 [==============================] - 3s 14ms/step - loss: 0.0018 - mean_absolute_error: 0.0018 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 2/9
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 3/9
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 4/9
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 5/9
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0015 - val_mean_absolute_error: 0.0015
# Epoch 6/9
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0015 - val_mean_absolute_error: 0.0015
# Epoch 7/9
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - val_loss: 0.0014 - val_mean_absolute_error: 0.0014
# Epoch 8/9
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - val_loss: 0.0014 - val_mean_absolute_error: 0.0014
# Epoch 9/9
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - val_loss: 0.0014 - val_mean_absolute_error: 0.0014
# ==================== TRAINING EPOCH = 10 ====================
# start training MCNN...
# train with 10 epochs and 1 batch size
# Epoch 1/10
# 252/252 [==============================] - 4s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0018 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 2/10
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 3/10
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 4/10
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016
# Epoch 5/10
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0015 - val_mean_absolute_error: 0.0015
# Epoch 6/10
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - val_loss: 0.0015 - val_mean_absolute_error: 0.0015
# Epoch 7/10
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - val_loss: 0.0014 - val_mean_absolute_error: 0.0014
# Epoch 8/10
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - val_loss: 0.0014 - val_mean_absolute_error: 0.0014
# Epoch 9/10
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - val_loss: 0.0014 - val_mean_absolute_error: 0.0014
# Epoch 10/10
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - val_loss: 0.0014 - val_mean_absolute_error: 0.0014

# %%
min_mae_epochs = np.argmin(mean_abs_err)
min_mse_epochs = np.argmin(mean_sqr_err)

print('Minumum MAE at epoch',min_mae_epochs+1,'with MAE =',mean_abs_err[min_mae_epochs])
print('Minumum MSE at epoch',min_mse_epochs+1,'with MSE =',mean_sqr_err[min_mse_epochs])

plt.figure(figsize=(20, 10))
plt.plot(np.arange(min_epochs, max_epochs+1),mean_abs_err, marker='x')
plt.plot(np.arange(min_epochs, max_epochs+1),mean_sqr_err, marker='x')
plt.xticks(np.arange(min_epochs, max_epochs+1))
plt.xlabel('# epochs')
plt.ylabel('Errors')
plt.legend(['MAE', 'MSE'])
plt.title('MAE and MSE per different epochs')
plt.show()
# Out:
# Minumum MAE at epoch 2 with MAE = 15.2
# Minumum MSE at epoch 2 with MSE = 19.524343778985248

# %%
for layer in model.layers[:-2]:
    layer.trainable = False
    
for layer in model.layers:
    print(layer, layer.trainable)
    

mcnn = models.Sequential()
mcnn.add(model)

mcnn.summary()
# Out:
# <keras.engine.input_layer.InputLayer object at 0x125e72470> False
# <keras.layers.convolutional.Conv2D object at 0x1312fc208> False
# <keras.layers.convolutional.Conv2D object at 0x125e72748> False
# <keras.layers.convolutional.Conv2D object at 0x131ce5438> False
# <keras.layers.pooling.MaxPooling2D object at 0x1313176a0> False
# <keras.layers.pooling.MaxPooling2D object at 0x125e72588> False
# <keras.layers.pooling.MaxPooling2D object at 0x131d033c8> False
# <keras.layers.convolutional.Conv2D object at 0x131317940> False
# <keras.layers.convolutional.Conv2D object at 0x125e72710> False
# <keras.layers.convolutional.Conv2D object at 0x131d03d68> False
# <keras.layers.pooling.MaxPooling2D object at 0x131cad2b0> False
# <keras.layers.pooling.MaxPooling2D object at 0x125ec5358> False
# <keras.layers.pooling.MaxPooling2D object at 0x131d3f080> False
# <keras.layers.convolutional.Conv2D object at 0x131cad5f8> False
# <keras.layers.convolutional.Conv2D object at 0x125ec5ef0> False
# <keras.layers.convolutional.Conv2D object at 0x131d3fcf8> False
# <keras.layers.convolutional.Conv2D object at 0x131ccb0f0> False
# <keras.layers.convolutional.Conv2D object at 0x12643d128> False
# <keras.layers.convolutional.Conv2D object at 0x131d5db70> False
# <keras.layers.merge.Concatenate object at 0x131d92198> True
# <keras.layers.convolutional.Conv2D object at 0x131d92160> True
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_2 (Model)              (None, None, None, 1)     127953
# =================================================================
# Total params: 127,953
# Trainable params: 31
# Non-trainable params: 127,922
# _________________________________________________________________

# %%
epochs = min_mae_epochs+1
# epochs = 10
batch_size = 1
aug = ImageDataGenerator()

train_generator = aug.flow(train, train_den, batch_size = batch_size, shuffle = True)
val_generator = aug.flow(val, val_den, batch_size = batch_size, shuffle = True)

# %%
mcnn.compile(loss='mae',
              optimizer=Adam(0.0001),
              metrics=['mae'])

print('start training MCNN...')
print("train with {} epochs and {} batch size".format(epochs, batch_size))
history = mcnn.fit_generator(train_generator,
                            steps_per_epoch = math.ceil(train.shape[0]/train_generator.batch_size),
                            epochs = epochs,
                            validation_data = val_generator,
                            validation_steps = math.ceil(val.shape[0]/val_generator.batch_size),
                            verbose = 1)

mcnn.save('keras_weight/trained.h5')
# Out:
# start training MCNN...
# train with 2 epochs and 1 batch size
# Epoch 1/2
# 252/252 [==============================] - 4s 14ms/step - loss: 0.0018 - mean_absolute_error: 0.0018 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 2/2
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - val_loss: 0.0016 - val_mean_absolute_error: 0.0016

# %%
mae = history.history['mean_absolute_error']
val_mae = history.history['val_mean_absolute_error']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(mae))
 
plt.plot(epochs, mae, 'b', label='Training mae')
plt.plot(epochs, val_mae, 'r', label='Validation mae')
plt.title('Training and validation MAE')
plt.legend()
 
plt.show()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()

# %% [markdown]
# ## Predict each image!
# Iterate over the preprocessed data (`data`) and predict total number of people of each image.

# %%
test_path = 'icanteen_img/test/images/'
data = test_preprocessing(test_path, 'icanteen')
# Out:
# loading data from dataset icanteen ...
# icanteen_img/test/images/IMG_1.jpg
# icanteen_img/test/images/IMG_10.jpg
# icanteen_img/test/images/IMG_11.jpg
# icanteen_img/test/images/IMG_12.jpg
# icanteen_img/test/images/IMG_13.jpg
# icanteen_img/test/images/IMG_14.jpg
# icanteen_img/test/images/IMG_15.jpg
# icanteen_img/test/images/IMG_16.jpg
# icanteen_img/test/images/IMG_17.jpg
# icanteen_img/test/images/IMG_18.jpg
# icanteen_img/test/images/IMG_19.jpg
# icanteen_img/test/images/IMG_2.jpg
# icanteen_img/test/images/IMG_20.jpg
# icanteen_img/test/images/IMG_21.jpg
# icanteen_img/test/images/IMG_22.jpg
# icanteen_img/test/images/IMG_23.jpg
# icanteen_img/test/images/IMG_24.jpg
# icanteen_img/test/images/IMG_25.jpg
# icanteen_img/test/images/IMG_26.jpg
# icanteen_img/test/images/IMG_27.jpg
# icanteen_img/test/images/IMG_28.jpg
# icanteen_img/test/images/IMG_29.jpg
# icanteen_img/test/images/IMG_3.jpg
# icanteen_img/test/images/IMG_30.jpg
# icanteen_img/test/images/IMG_4.jpg
# icanteen_img/test/images/IMG_5.jpg
# icanteen_img/test/images/IMG_6.jpg
# icanteen_img/test/images/IMG_7.jpg
# icanteen_img/test/images/IMG_8.jpg
# icanteen_img/test/images/IMG_9.jpg
# load data finished.

# %%
mae = 0
mse = 0
ground_truth = get_ground_truth('test')
pred = []

mcnn.load_weights('keras_weight/trained.h5')

initial_num = 36
i = 0
for d in data:
    inputs = np.reshape(d, [1, d.shape[0], d.shape[1], 1])
    outputs = mcnn.predict(inputs)
    c_pre = round(np.sum(outputs))
    pred.append(c_pre)
    print('='*10+'IMG_'+str(i+initial_num)+'.jpg'+'='*10)
    print('IMG_'+str(i+initial_num),'predicted ', c_pre,'people')
    print('IMG_'+str(i+initial_num),'actual',ground_truth[i], 'people')
    mae += abs(ground_truth[i]-c_pre)
    mse += (ground_truth[i]-c_pre)**2
    print('ERROR:',abs(ground_truth[i]-c_pre))
    print('current MAE:',mae/(i+1))
    print('current MSE:',(mse/(i+1))**0.5)
    
#     plt.figure(figsize=(15, 7.5))
#     plt.imshow(inputs.reshape(inputs.shape[1], inputs.shape[2]), cmap='gray')
#     plt.title('test_'+str(i+1))
#     plt.xticks([])
#     plt.yticks([])
#     plt.show()
#     plt.figure(figsize=(15, 7.5))
    
    den = outputs.reshape(outputs.shape[1], outputs.shape[2])
#     plt.imshow(den)
#     plt.title('heatmap_IMG_'+str(i+1))
#     plt.xticks([])
#     plt.yticks([])
#     plt.show()
    
    den_name = 'heat_'+'IMG_'+str(i+initial_num)+'.png'
    plt.imsave('icanteen_heat/'+den_name, den)
    i += 1
    
print('Mean Absolute Error:',mae/len(ground_truth))
print('Mean Square Error:',math.sqrt(mse/len(ground_truth)))

plt.figure(figsize=(20, 10))
plt.plot(np.arange(1,len(ground_truth)+1),ground_truth, marker='x')
plt.plot(np.arange(1,len(ground_truth)+1),pred, marker='x')
plt.xticks(np.arange(1,len(ground_truth)+1))
plt.xlabel('Img no.')
plt.ylabel('People')
plt.legend(['ground truth', 'pred'])
plt.title('Head counts Actual vs Predict')
plt.show()
# Out:
# ==========IMG_36.jpg==========
# IMG_36 predicted  165.0 people
# IMG_36 actual 186 people
# ERROR: 21.0
# current MAE: 21.0
# current MSE: 21.0
# ==========IMG_37.jpg==========
# IMG_37 predicted  117.0 people
# IMG_37 actual 140 people
# ERROR: 23.0
# current MAE: 22.0
# current MSE: 22.02271554554524
# ==========IMG_38.jpg==========
# IMG_38 predicted  138.0 people
# IMG_38 actual 96 people
# ERROR: 42.0
# current MAE: 28.666666666666668
# current MSE: 30.18829795356693
# ==========IMG_39.jpg==========
# IMG_39 predicted  175.0 people
# IMG_39 actual 172 people
# ERROR: 3.0
# current MAE: 22.25
# current MSE: 26.186828750346997
# ==========IMG_40.jpg==========
# IMG_40 predicted  117.0 people
# IMG_40 actual 137 people
# ERROR: 20.0
# current MAE: 21.8
# current MSE: 25.071896617527763
# ==========IMG_41.jpg==========
# IMG_41 predicted  146.0 people
# IMG_41 actual 115 people
# ERROR: 31.0
# current MAE: 23.333333333333332
# current MSE: 26.153393661244042
# ==========IMG_42.jpg==========
# IMG_42 predicted  146.0 people
# IMG_42 actual 126 people
# ERROR: 20.0
# current MAE: 22.857142857142858
# current MSE: 25.365893862203464
# ==========IMG_43.jpg==========
# IMG_43 predicted  163.0 people
# IMG_43 actual 183 people
# ERROR: 20.0
# current MAE: 22.5
# current MSE: 24.758836806279895
# ==========IMG_44.jpg==========
# IMG_44 predicted  91.0 people
# IMG_44 actual 128 people
# ERROR: 37.0
# current MAE: 24.11111111111111
# current MSE: 26.40075756488817
# ==========IMG_45.jpg==========
# IMG_45 predicted  93.0 people
# IMG_45 actual 68 people
# ERROR: 25.0
# current MAE: 24.2
# current MSE: 26.26404386228442
# ==========IMG_46.jpg==========
# IMG_46 predicted  116.0 people
# IMG_46 actual 120 people
# ERROR: 4.0
# current MAE: 22.363636363636363
# current MSE: 25.070808813148698
# ==========IMG_47.jpg==========
# IMG_47 predicted  122.0 people
# IMG_47 actual 140 people
# ERROR: 18.0
# current MAE: 22.0
# current MSE: 24.559451676832417
# ==========IMG_48.jpg==========
# IMG_48 predicted  111.0 people
# IMG_48 actual 110 people
# ERROR: 1.0
# current MAE: 20.384615384615383
# current MSE: 23.59758788194577
# ==========IMG_49.jpg==========
# IMG_49 predicted  27.0 people
# IMG_49 actual 17 people
# ERROR: 10.0
# current MAE: 19.642857142857142
# current MSE: 22.895726363544043
# ==========IMG_50.jpg==========
# IMG_50 predicted  106.0 people
# IMG_50 actual 100 people
# ERROR: 6.0
# current MAE: 18.733333333333334
# current MSE: 22.173557826083453
# ==========IMG_51.jpg==========
# IMG_51 predicted  164.0 people
# IMG_51 actual 186 people
# ERROR: 22.0
# current MAE: 18.9375
# current MSE: 22.16275028059469
# ==========IMG_52.jpg==========
# IMG_52 predicted  101.0 people
# IMG_52 actual 131 people
# ERROR: 30.0
# current MAE: 19.58823529411765
# current MSE: 22.698794992634458
# ==========IMG_53.jpg==========
# IMG_53 predicted  94.0 people
# IMG_53 actual 136 people
# ERROR: 42.0
# current MAE: 20.833333333333332
# current MSE: 24.178732620034307
# ==========IMG_54.jpg==========
# IMG_54 predicted  138.0 people
# IMG_54 actual 123 people
# ERROR: 15.0
# current MAE: 20.526315789473685
# current MSE: 23.784116769943672
# ==========IMG_55.jpg==========
# IMG_55 predicted  168.0 people
# IMG_55 actual 148 people
# ERROR: 20.0
# current MAE: 20.5
# current MSE: 23.609320193516798
# ==========IMG_56.jpg==========
# IMG_56 predicted  51.0 people
# IMG_56 actual 56 people
# ERROR: 5.0
# current MAE: 19.761904761904763
# current MSE: 23.066157440016294
# ==========IMG_57.jpg==========
# IMG_57 predicted  55.0 people
# IMG_57 actual 52 people
# ERROR: 3.0
# current MAE: 19.0
# current MSE: 22.544904685376853
# ==========IMG_58.jpg==========
# IMG_58 predicted  119.0 people
# IMG_58 actual 143 people
# ERROR: 24.0
# current MAE: 19.217391304347824
# current MSE: 22.610117012177266
# ==========IMG_59.jpg==========
# IMG_59 predicted  42.0 people
# IMG_59 actual 35 people
# ERROR: 7.0
# current MAE: 18.708333333333332
# current MSE: 22.18013375372956
# ==========IMG_60.jpg==========
# IMG_60 predicted  142.0 people
# IMG_60 actual 165 people
# ERROR: 23.0
# current MAE: 18.88
# current MSE: 22.213509403063714
# ==========IMG_61.jpg==========
# IMG_61 predicted  103.0 people
# IMG_61 actual 141 people
# ERROR: 38.0
# current MAE: 19.615384615384617
# current MSE: 23.021728866442675
# ==========IMG_62.jpg==========
# IMG_62 predicted  133.0 people
# IMG_62 actual 129 people
# ERROR: 4.0
# current MAE: 19.037037037037038
# current MSE: 22.604489885041932
# ==========IMG_63.jpg==========
# IMG_63 predicted  131.0 people
# IMG_63 actual 116 people
# ERROR: 15.0
# current MAE: 18.892857142857142
# current MSE: 22.377444000600246
# ==========IMG_64.jpg==========
# IMG_64 predicted  137.0 people
# IMG_64 actual 130 people
# ERROR: 7.0
# current MAE: 18.482758620689655
# current MSE: 22.026629651244953
# ==========IMG_65.jpg==========
# IMG_65 predicted  115.0 people
# IMG_65 actual 139 people
# ERROR: 24.0
# current MAE: 18.666666666666668
# current MSE: 22.09524835796149
# Mean Absolute Error: 18.666666666666668
# Mean Square Error: 22.09524835796149

# %% [markdown]
# ## Visualizing weights

# %%
def display_activation(activations, col_size, row_size, act_index): 
    activation = activations[act_index]
    activation_index=0
    fig, ax = plt.subplots(row_size, col_size, figsize=(row_size*2.5,col_size*1.5))
    for row in range(0,row_size):
        for col in range(0,col_size):
            ax[row][col].imshow(activation[0, :, :, activation_index], cmap='gray')
            activation_index += 1

# %%
mcnn.model.inputs
# Out:
# /home/tan_epacsp/anaconda3/lib/python3.5/site-packages/keras/engine/sequential.py:110: UserWarning: `Sequential.model` is deprecated. `Sequential` is a subclass of `Model`, you can just use your `Sequential` instance directly.
#   warnings.warn('`Sequential.model` is deprecated. '
# [<tf.Tensor 'model_1_input:0' shape=(?, ?, ?, 1) dtype=float32>]

# %% [markdown]
# ## HTTP Post on a server
# In this cell, we are trying to do a **HTTP POST** command to send a JSON object (containing head counted and current timestamp) to the server.

# %%
import requests
import datetime

def http_POST_current_time(head_count):
    db_path = 'https://enqzgrfms9dop.x.pipedream.net/'
    currentDT = datetime.datetime.now()
    YYMMDD = str(currentDT.year)+'-'+str(currentDT.month)+'-'+str(currentDT.day)
    TIME = str(currentDT.hour)+':'+str(currentDT.minute)+':'+str(currentDT.second)
    date = YYMMDD + ' ' + TIME
    data = {
        'time_stamp': date,
        'crowd_size': head_count
    }

    r = requests.post(db_path, data=data)
    
http_POST_current_time(5)
